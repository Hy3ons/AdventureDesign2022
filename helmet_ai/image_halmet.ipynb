# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from google.colab.patches import cv2_imshow
from google.colab import drive
import tensorflow as tf
import os
import PIL
import shutil
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.image as mpimg
from sklearn.model_selection import KFold
from tensorflow.keras.optimizers import RMSprop
drive.mount('/content/drive')
from sklearn.model_selection import train_test_split
import cv2
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-1-937524b076e8> in <module>
#      15 from sklearn.model_selection import KFold
#      16 from tensorflow.keras.optimizers import RMSprop
# ---> 17 drive.mount('/content/drive')
#      18 from sklearn.model_selection import train_test_split
#      19 import cv2
#
# /usr/local/lib/python3.8/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      99 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#     100   """Mount your Google Drive at the specified mountpoint path."""
# --> 101   return _mount(
#     102       mountpoint,
#     103       force_remount=force_remount,
#
# /usr/local/lib/python3.8/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     122       'TBE_EPHEM_CREDS_ADDR'] if ephemeral else _os.environ['TBE_CREDS_ADDR']
#     123   if ephemeral:
# --> 124     _message.blocking_request(
#     125         'request_auth', request={'authType': 'dfs_ephemeral'}, timeout_sec=None)
#     126
#
# /usr/local/lib/python3.8/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     169   request_id = send_request(
#     170       request_type, request, parent=parent, expect_reply=True)
# --> 171   return read_reply_from_input(request_id, timeout_sec)
#
# /usr/local/lib/python3.8/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     100         reply.get('colab_msg_id') == message_id):
#     101       if 'error' in reply:
# --> 102         raise MessageError(reply['error'])
#     103       return reply.get('data', None)
#     104
#
# MessageError: Error: credential propagation was unsuccessful

# %%
base_dir = '/content/drive/MyDrive/halmet'
train_dir = os.path.join(base_dir, 'train')
test_dir = os.path.join(base_dir, 'test')
vali_dir = os.path.join(base_dir, 'vali')

train_h_dir = os.path.join(train_dir, 'halmet')
train_f_dir = os.path.join(train_dir, 'face')

vali_h_dir = os.path.join(vali_dir, 'halmet')
vali_f_dir = os.path.join(vali_dir, 'face')

test_h_dir = os.path.join(test_dir, 'halmet')
test_f_dir = os.path.join(test_dir, 'face')
print(vali_h_dir)
# Out:
# /content/drive/MyDrive/halmet/vali/halmet

# %%
train_data_augmentation = ImageDataGenerator(rescale = 1./255,width_shift_range=0.2,height_shift_range=0.2,zoom_range=0.2,horizontal_flip=True,vertical_flip=False,fill_mode='nearest') 
test_data = ImageDataGenerator(rescale = 1./255) 
vali_data = ImageDataGenerator(rescale = 1./255)

# %%
train_generator = train_data_augmentation.flow_from_directory(train_dir,batch_size=20,class_mode='binary',target_size=(200,200)) 
vali_generator = vali_data.flow_from_directory(vali_dir,batch_size=4,class_mode='binary',target_size=(200,200))
test_generator = test_data.flow_from_directory(test_dir,batch_size=4,class_mode='binary',target_size=(200,200))
print(train_generator.class_indices)
# Out:
# Found 301 images belonging to 2 classes.
# Found 89 images belonging to 2 classes.
# Found 10 images belonging to 2 classes.
# {'face': 0, 'halmet': 1}

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(64, (3,3), activation='relu', input_shape=(200, 200, 3)),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# %%
model.compile(optimizer=RMSprop(learning_rate=0.001),
              loss='binary_crossentropy',
              metrics= ['accuracy'])

# %%
history = model.fit_generator(train_generator,validation_data=vali_generator,steps_per_epoch=4,epochs=100,validation_steps=4,verbose=2)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   """Entry point for launching an IPython kernel.
# Epoch 1/100
# 4/4 - 14s - loss: 4.2866 - accuracy: 0.4000 - val_loss: 0.7171 - val_accuracy: 0.5000 - 14s/epoch - 4s/step
# Epoch 2/100
# 4/4 - 11s - loss: 1.0199 - accuracy: 0.4625 - val_loss: 0.7153 - val_accuracy: 0.5625 - 11s/epoch - 3s/step
# Epoch 3/100
# 4/4 - 9s - loss: 0.8321 - accuracy: 0.4750 - val_loss: 0.6857 - val_accuracy: 0.6250 - 9s/epoch - 2s/step
# Epoch 4/100
# 4/4 - 7s - loss: 0.7712 - accuracy: 0.3770 - val_loss: 0.6902 - val_accuracy: 0.4375 - 7s/epoch - 2s/step
# Epoch 5/100
# 4/4 - 7s - loss: 0.6976 - accuracy: 0.4754 - val_loss: 0.7057 - val_accuracy: 0.3750 - 7s/epoch - 2s/step
# Epoch 6/100
# 4/4 - 7s - loss: 0.6479 - accuracy: 0.6000 - val_loss: 1.1095 - val_accuracy: 0.5625 - 7s/epoch - 2s/step
# Epoch 7/100
# 4/4 - 6s - loss: 0.7727 - accuracy: 0.5125 - val_loss: 0.6650 - val_accuracy: 0.5625 - 6s/epoch - 1s/step
# Epoch 8/100
# 4/4 - 4s - loss: 0.6918 - accuracy: 0.5574 - val_loss: 0.6582 - val_accuracy: 0.5625 - 4s/epoch - 911ms/step
# Epoch 9/100
# 4/4 - 4s - loss: 0.6608 - accuracy: 0.5410 - val_loss: 0.6836 - val_accuracy: 0.5625 - 4s/epoch - 998ms/step
# Epoch 10/100
# 4/4 - 3s - loss: 0.6724 - accuracy: 0.5738 - val_loss: 0.6786 - val_accuracy: 0.5625 - 3s/epoch - 700ms/step
# Epoch 11/100
# 4/4 - 3s - loss: 0.6422 - accuracy: 0.5410 - val_loss: 0.8244 - val_accuracy: 0.5000 - 3s/epoch - 742ms/step
# Epoch 12/100
# 4/4 - 5s - loss: 0.6457 - accuracy: 0.4500 - val_loss: 0.6932 - val_accuracy: 0.5625 - 5s/epoch - 1s/step
# Epoch 13/100
# 4/4 - 4s - loss: 0.5992 - accuracy: 0.6250 - val_loss: 0.5692 - val_accuracy: 0.8750 - 4s/epoch - 902ms/step
# Epoch 14/100
# 4/4 - 4s - loss: 0.6518 - accuracy: 0.5750 - val_loss: 0.8369 - val_accuracy: 0.5000 - 4s/epoch - 955ms/step
# Epoch 15/100
# 4/4 - 3s - loss: 0.5793 - accuracy: 0.6721 - val_loss: 1.0996 - val_accuracy: 0.4375 - 3s/epoch - 696ms/step
# Epoch 16/100
# 4/4 - 3s - loss: 0.7564 - accuracy: 0.6000 - val_loss: 0.6929 - val_accuracy: 0.5000 - 3s/epoch - 854ms/step
# Epoch 17/100
# 4/4 - 3s - loss: 0.6497 - accuracy: 0.6230 - val_loss: 0.6566 - val_accuracy: 0.7500 - 3s/epoch - 693ms/step
# Epoch 18/100
# 4/4 - 3s - loss: 0.7757 - accuracy: 0.5574 - val_loss: 0.6765 - val_accuracy: 0.5625 - 3s/epoch - 795ms/step
# Epoch 19/100
# 4/4 - 4s - loss: 0.6393 - accuracy: 0.7250 - val_loss: 0.5689 - val_accuracy: 0.7500 - 4s/epoch - 935ms/step
# Epoch 20/100
# 4/4 - 3s - loss: 0.6099 - accuracy: 0.6875 - val_loss: 0.5921 - val_accuracy: 0.7500 - 3s/epoch - 843ms/step
# Epoch 21/100
# 4/4 - 3s - loss: 0.6288 - accuracy: 0.6625 - val_loss: 0.8518 - val_accuracy: 0.5000 - 3s/epoch - 807ms/step
# Epoch 22/100
# 4/4 - 4s - loss: 0.6675 - accuracy: 0.5738 - val_loss: 2.7566 - val_accuracy: 0.5625 - 4s/epoch - 878ms/step
# Epoch 23/100
# 4/4 - 3s - loss: 1.5686 - accuracy: 0.6500 - val_loss: 0.5900 - val_accuracy: 0.6250 - 3s/epoch - 815ms/step
# Epoch 24/100
# 4/4 - 3s - loss: 0.6079 - accuracy: 0.6000 - val_loss: 0.6028 - val_accuracy: 0.6250 - 3s/epoch - 805ms/step
# Epoch 25/100
# 4/4 - 3s - loss: 0.5750 - accuracy: 0.8000 - val_loss: 0.4882 - val_accuracy: 0.7500 - 3s/epoch - 823ms/step
# Epoch 26/100
# 4/4 - 3s - loss: 0.6242 - accuracy: 0.6557 - val_loss: 0.5735 - val_accuracy: 0.6250 - 3s/epoch - 811ms/step
# Epoch 27/100
# 4/4 - 3s - loss: 0.5601 - accuracy: 0.6625 - val_loss: 0.5180 - val_accuracy: 0.8125 - 3s/epoch - 813ms/step
# Epoch 28/100
# 4/4 - 3s - loss: 0.6057 - accuracy: 0.6875 - val_loss: 0.5001 - val_accuracy: 0.7500 - 3s/epoch - 817ms/step
# Epoch 29/100
# 4/4 - 3s - loss: 0.4711 - accuracy: 0.8625 - val_loss: 0.6237 - val_accuracy: 0.7500 - 3s/epoch - 840ms/step
# Epoch 30/100
# 4/4 - 3s - loss: 0.4635 - accuracy: 0.7625 - val_loss: 0.3124 - val_accuracy: 0.8750 - 3s/epoch - 792ms/step
# Epoch 31/100
# 4/4 - 3s - loss: 0.5933 - accuracy: 0.6875 - val_loss: 0.6178 - val_accuracy: 0.6875 - 3s/epoch - 787ms/step
# Epoch 32/100
# 4/4 - 3s - loss: 0.4899 - accuracy: 0.7500 - val_loss: 0.6046 - val_accuracy: 0.6875 - 3s/epoch - 797ms/step
# Epoch 33/100
# 4/4 - 3s - loss: 0.4459 - accuracy: 0.8375 - val_loss: 0.7223 - val_accuracy: 0.6250 - 3s/epoch - 764ms/step
# Epoch 34/100
# 4/4 - 3s - loss: 0.5552 - accuracy: 0.7377 - val_loss: 1.2667 - val_accuracy: 0.5625 - 3s/epoch - 687ms/step
# Epoch 35/100
# 4/4 - 3s - loss: 0.6214 - accuracy: 0.7000 - val_loss: 0.6176 - val_accuracy: 0.6875 - 3s/epoch - 799ms/step
# Epoch 36/100
# 4/4 - 3s - loss: 0.4958 - accuracy: 0.7875 - val_loss: 0.2928 - val_accuracy: 1.0000 - 3s/epoch - 806ms/step
# Epoch 37/100
# 4/4 - 3s - loss: 0.4491 - accuracy: 0.8250 - val_loss: 0.8978 - val_accuracy: 0.6875 - 3s/epoch - 721ms/step
# Epoch 38/100
# 4/4 - 3s - loss: 0.8212 - accuracy: 0.6500 - val_loss: 0.4009 - val_accuracy: 0.8750 - 3s/epoch - 834ms/step
# Epoch 39/100
# 4/4 - 3s - loss: 0.4498 - accuracy: 0.8125 - val_loss: 0.3482 - val_accuracy: 0.7500 - 3s/epoch - 840ms/step
# Epoch 40/100
# 4/4 - 3s - loss: 0.4805 - accuracy: 0.8250 - val_loss: 0.7823 - val_accuracy: 0.5000 - 3s/epoch - 814ms/step
# Epoch 41/100
# 4/4 - 3s - loss: 0.4542 - accuracy: 0.8000 - val_loss: 0.2757 - val_accuracy: 0.9375 - 3s/epoch - 745ms/step
# Epoch 42/100
# 4/4 - 3s - loss: 0.4715 - accuracy: 0.8125 - val_loss: 0.4085 - val_accuracy: 0.6875 - 3s/epoch - 778ms/step
# Epoch 43/100
# 4/4 - 3s - loss: 0.3728 - accuracy: 0.8361 - val_loss: 0.3918 - val_accuracy: 0.8750 - 3s/epoch - 676ms/step
# Epoch 44/100
# 4/4 - 3s - loss: 0.7840 - accuracy: 0.7375 - val_loss: 0.7335 - val_accuracy: 0.6250 - 3s/epoch - 792ms/step
# Epoch 45/100
# 4/4 - 3s - loss: 0.9860 - accuracy: 0.6066 - val_loss: 0.4682 - val_accuracy: 0.6875 - 3s/epoch - 656ms/step
# Epoch 46/100
# 4/4 - 3s - loss: 0.4792 - accuracy: 0.7750 - val_loss: 0.3695 - val_accuracy: 0.8750 - 3s/epoch - 792ms/step
# Epoch 47/100
# 4/4 - 3s - loss: 0.4144 - accuracy: 0.8125 - val_loss: 0.1418 - val_accuracy: 1.0000 - 3s/epoch - 789ms/step
# Epoch 48/100
# 4/4 - 2s - loss: 0.4171 - accuracy: 0.8033 - val_loss: 0.3445 - val_accuracy: 0.7500 - 2s/epoch - 621ms/step
# Epoch 49/100
# 4/4 - 3s - loss: 0.3804 - accuracy: 0.8375 - val_loss: 0.5293 - val_accuracy: 0.6875 - 3s/epoch - 754ms/step
# Epoch 50/100
# 4/4 - 3s - loss: 1.1404 - accuracy: 0.7377 - val_loss: 0.4713 - val_accuracy: 0.8750 - 3s/epoch - 682ms/step
# Epoch 51/100
# 4/4 - 3s - loss: 0.5847 - accuracy: 0.6875 - val_loss: 0.3542 - val_accuracy: 0.8750 - 3s/epoch - 846ms/step
# Epoch 52/100
# 4/4 - 3s - loss: 0.4928 - accuracy: 0.8125 - val_loss: 0.6434 - val_accuracy: 0.5000 - 3s/epoch - 809ms/step
# Epoch 53/100
# 4/4 - 3s - loss: 0.4316 - accuracy: 0.8000 - val_loss: 0.5731 - val_accuracy: 0.7500 - 3s/epoch - 822ms/step
# Epoch 54/100
# 4/4 - 2s - loss: 0.3987 - accuracy: 0.8361 - val_loss: 0.7501 - val_accuracy: 0.6875 - 2s/epoch - 615ms/step
# Epoch 55/100
# 4/4 - 3s - loss: 0.7473 - accuracy: 0.7250 - val_loss: 0.5435 - val_accuracy: 0.7500 - 3s/epoch - 801ms/step
# Epoch 56/100
# 4/4 - 3s - loss: 0.3862 - accuracy: 0.8197 - val_loss: 0.4687 - val_accuracy: 0.6875 - 3s/epoch - 646ms/step
# Epoch 57/100
# 4/4 - 3s - loss: 0.2908 - accuracy: 0.8375 - val_loss: 0.4146 - val_accuracy: 0.7500 - 3s/epoch - 776ms/step
# Epoch 58/100
# 4/4 - 3s - loss: 0.2994 - accuracy: 0.8750 - val_loss: 0.3609 - val_accuracy: 0.8125 - 3s/epoch - 792ms/step
# Epoch 59/100
# 4/4 - 3s - loss: 0.4888 - accuracy: 0.7869 - val_loss: 0.5154 - val_accuracy: 0.6875 - 3s/epoch - 732ms/step
# Epoch 60/100
# 4/4 - 3s - loss: 0.3843 - accuracy: 0.7500 - val_loss: 0.4191 - val_accuracy: 0.8125 - 3s/epoch - 765ms/step
# Epoch 61/100
# 4/4 - 3s - loss: 0.4149 - accuracy: 0.8375 - val_loss: 0.2833 - val_accuracy: 0.9375 - 3s/epoch - 820ms/step
# Epoch 62/100
# 4/4 - 3s - loss: 0.3137 - accuracy: 0.8852 - val_loss: 0.2898 - val_accuracy: 0.8125 - 3s/epoch - 671ms/step
# Epoch 63/100
# 4/4 - 3s - loss: 0.3514 - accuracy: 0.8375 - val_loss: 1.1248 - val_accuracy: 0.4375 - 3s/epoch - 836ms/step
# Epoch 64/100
# 4/4 - 3s - loss: 0.4657 - accuracy: 0.8000 - val_loss: 0.2371 - val_accuracy: 0.9375 - 3s/epoch - 802ms/step
# Epoch 65/100
# 4/4 - 3s - loss: 0.3484 - accuracy: 0.8250 - val_loss: 0.4827 - val_accuracy: 0.7500 - 3s/epoch - 797ms/step
# Epoch 66/100
# 4/4 - 3s - loss: 0.4255 - accuracy: 0.8125 - val_loss: 0.3937 - val_accuracy: 0.8125 - 3s/epoch - 794ms/step
# Epoch 67/100
# 4/4 - 3s - loss: 0.2649 - accuracy: 0.9180 - val_loss: 0.4282 - val_accuracy: 0.8750 - 3s/epoch - 689ms/step
# Epoch 68/100
# 4/4 - 3s - loss: 0.6510 - accuracy: 0.7541 - val_loss: 0.6783 - val_accuracy: 0.6250 - 3s/epoch - 669ms/step
# Epoch 69/100
# 4/4 - 3s - loss: 0.8148 - accuracy: 0.7541 - val_loss: 0.3035 - val_accuracy: 0.7500 - 3s/epoch - 678ms/step
# Epoch 70/100
# 4/4 - 3s - loss: 0.3561 - accuracy: 0.8750 - val_loss: 0.6060 - val_accuracy: 0.6250 - 3s/epoch - 812ms/step
# Epoch 71/100
# 4/4 - 3s - loss: 0.4949 - accuracy: 0.8525 - val_loss: 0.3031 - val_accuracy: 0.8750 - 3s/epoch - 640ms/step
# Epoch 72/100
# 4/4 - 3s - loss: 0.2676 - accuracy: 0.9375 - val_loss: 0.5266 - val_accuracy: 0.6250 - 3s/epoch - 754ms/step
# Epoch 73/100
# 4/4 - 3s - loss: 0.3652 - accuracy: 0.8375 - val_loss: 0.3247 - val_accuracy: 0.8125 - 3s/epoch - 771ms/step
# Epoch 74/100
# 4/4 - 3s - loss: 0.3657 - accuracy: 0.8375 - val_loss: 0.3084 - val_accuracy: 0.8750 - 3s/epoch - 800ms/step
# Epoch 75/100
# 4/4 - 3s - loss: 0.2700 - accuracy: 0.9000 - val_loss: 0.2659 - val_accuracy: 0.8750 - 3s/epoch - 757ms/step
# Epoch 76/100
# 4/4 - 3s - loss: 0.5005 - accuracy: 0.7049 - val_loss: 0.6615 - val_accuracy: 0.6875 - 3s/epoch - 645ms/step
# Epoch 77/100
# 4/4 - 4s - loss: 0.2669 - accuracy: 0.8875 - val_loss: 0.6813 - val_accuracy: 0.6875 - 4s/epoch - 1s/step
# Epoch 78/100
# 4/4 - 4s - loss: 0.3241 - accuracy: 0.8250 - val_loss: 0.2401 - val_accuracy: 0.8750 - 4s/epoch - 903ms/step
# Epoch 79/100
# 4/4 - 2s - loss: 0.2614 - accuracy: 0.9016 - val_loss: 0.9671 - val_accuracy: 0.6875 - 2s/epoch - 617ms/step
# Epoch 80/100
# 4/4 - 3s - loss: 0.1438 - accuracy: 0.9344 - val_loss: 0.1776 - val_accuracy: 0.9375 - 3s/epoch - 654ms/step
# Epoch 81/100
# 4/4 - 3s - loss: 0.7095 - accuracy: 0.7125 - val_loss: 0.4232 - val_accuracy: 0.7500 - 3s/epoch - 784ms/step
# Epoch 82/100
# 4/4 - 3s - loss: 0.8407 - accuracy: 0.7750 - val_loss: 0.4201 - val_accuracy: 0.7500 - 3s/epoch - 723ms/step
# Epoch 83/100
# 4/4 - 3s - loss: 0.3493 - accuracy: 0.9000 - val_loss: 0.5780 - val_accuracy: 0.7500 - 3s/epoch - 758ms/step
# Epoch 84/100
# 4/4 - 3s - loss: 0.2366 - accuracy: 0.9344 - val_loss: 1.6435 - val_accuracy: 0.5000 - 3s/epoch - 644ms/step
# Epoch 85/100
# 4/4 - 3s - loss: 0.5562 - accuracy: 0.7375 - val_loss: 0.1791 - val_accuracy: 1.0000 - 3s/epoch - 777ms/step
# Epoch 86/100
# 4/4 - 3s - loss: 0.3332 - accuracy: 0.8625 - val_loss: 1.1497 - val_accuracy: 0.6875 - 3s/epoch - 740ms/step
# Epoch 87/100
# 4/4 - 3s - loss: 0.2730 - accuracy: 0.9000 - val_loss: 0.2750 - val_accuracy: 0.9375 - 3s/epoch - 797ms/step
# Epoch 88/100
# 4/4 - 3s - loss: 0.3044 - accuracy: 0.8500 - val_loss: 0.3080 - val_accuracy: 0.8125 - 3s/epoch - 816ms/step
# Epoch 89/100
# 4/4 - 3s - loss: 0.2534 - accuracy: 0.9000 - val_loss: 2.1247 - val_accuracy: 0.5000 - 3s/epoch - 770ms/step
# Epoch 90/100
# 4/4 - 3s - loss: 0.5979 - accuracy: 0.7375 - val_loss: 0.2305 - val_accuracy: 0.8750 - 3s/epoch - 767ms/step
# Epoch 91/100
# 4/4 - 3s - loss: 0.3375 - accuracy: 0.8500 - val_loss: 0.6515 - val_accuracy: 0.6875 - 3s/epoch - 768ms/step
# Epoch 92/100
# 4/4 - 3s - loss: 0.2605 - accuracy: 0.8852 - val_loss: 0.3344 - val_accuracy: 0.8125 - 3s/epoch - 646ms/step
# Epoch 93/100
# 4/4 - 3s - loss: 0.2292 - accuracy: 0.9250 - val_loss: 0.6884 - val_accuracy: 0.6875 - 3s/epoch - 759ms/step
# Epoch 94/100
# 4/4 - 3s - loss: 0.2305 - accuracy: 0.9375 - val_loss: 0.6174 - val_accuracy: 0.7500 - 3s/epoch - 796ms/step
# Epoch 95/100
# 4/4 - 3s - loss: 0.3338 - accuracy: 0.8033 - val_loss: 0.3056 - val_accuracy: 0.8750 - 3s/epoch - 687ms/step
# Epoch 96/100
# 4/4 - 3s - loss: 0.4080 - accuracy: 0.8250 - val_loss: 0.5406 - val_accuracy: 0.7500 - 3s/epoch - 772ms/step
# Epoch 97/100
# 4/4 - 3s - loss: 0.2534 - accuracy: 0.8750 - val_loss: 0.1838 - val_accuracy: 0.8750 - 3s/epoch - 787ms/step
# Epoch 98/100
# 4/4 - 3s - loss: 0.2276 - accuracy: 0.8750 - val_loss: 0.3970 - val_accuracy: 0.7500 - 3s/epoch - 806ms/step
# Epoch 99/100
# 4/4 - 3s - loss: 0.2187 - accuracy: 0.9250 - val_loss: 0.1696 - val_accuracy: 0.8750 - 3s/epoch - 799ms/step
# Epoch 100/100
# 4/4 - 3s - loss: 0.1884 - accuracy: 0.9000 - val_loss: 0.0091 - val_accuracy: 1.0000 - 3s/epoch - 769ms/step

# %%
# !git clone https://(leadjh1118):(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)@github.com/(leadjh1118)/(sddssds).git
# Out:
# /bin/bash: -c: line 0: syntax error near unexpected token `('
# /bin/bash: -c: line 0: `git clone https://(leadjh1118):(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)@github.com/(leadjh1118)/(sddssds).git'

# %%
model.evaluate(train_generator)
model.evaluate(test_generator)
# Out:
#  1/43 [..............................] - ETA: 15s - loss: 1.3419 - accuracy: 0.4286
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-7547682ddf98> in <module>
# ----> 1 model.evaluate(train_generator)
#       2 model.evaluate(test_generator)
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict, **kwargs)
#    1754             with tf.profiler.experimental.Trace('test', step_num=step, _r=1):
#    1755               callbacks.on_test_batch_begin(step)
# -> 1756               tmp_logs = self.test_function(iterator)
#    1757               if data_handler.should_sync:
#    1758                 context.async_wait()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     913
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#     917       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     952       # In this case we have not created variables on the first call. So we can
#     953       # run the first trace but we should fail if variables are created.
# --> 954       results = self._stateful_fn(*args, **kwds)
#     955       if self._created_variables and not ALLOW_DYNAMIC_VARIABLE_CREATION:
#     956         raise ValueError("Creating variables on a non-first call to a function"
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2452        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2453     return graph_function._call_flat(
# -> 2454         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2455
#    2456   @property
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1859       # No tape is watching; skip to running the function.
#    1860       return self._build_call_outputs(self._inference_function.call(
# -> 1861           ctx, args, cancellation_manager=cancellation_manager))
#    1862     forward_backward = self._select_forward_and_backward_functions(
#    1863         args,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     500               inputs=args,
#     501               attrs=attrs,
# --> 502               ctx=ctx)
#     503         else:
#     504           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      53     ctx.ensure_initialized()
#      54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#      57     if name is not None:
#
# KeyboardInterrupt:
